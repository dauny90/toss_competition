# %%
import xgboost as xgb
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_auc_score

# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_parquet('../data/train/train_sample.parquet')

# %%
train_df['inventory_id'] = train_df['inventory_id'].astype("category")
##train_df['inventory_id'].describe()

# %%
print(train_df.dtypes)
# Out:
# gender               str
# age_group            str
# inventory_id    category
# day_of_week          str
# hour                 str
#                   ...
# seq_len            int64
# unique_pages       int64
# last_page          int64
# first_page         int64
# repeat_ratio     float64
# Length: 123, dtype: object

# %%
def featurize(seq):
    pages = list(map(int, seq.split(",")))

    return {
        "seq_len": len(pages),
        "unique_pages": len(set(pages)),
        "last_page": pages[-1],
        "first_page": pages[0],
        #"has_page_75": int(75 in pages),
        "repeat_ratio": 1 - len(set(pages)) / len(pages)
    }

# %%
features = train_df["seq"].apply(featurize)

# %%
df_features = pd.DataFrame(features.tolist())

# %%
train_df.drop(columns=['seq'],inplace = True)

# %%
train_df = pd.concat([train_df, df_features], axis=1)

# %%
train_df.head()
# Out:
#   gender age_group inventory_id day_of_week hour  l_feat_1  l_feat_2  \
# 0    1.0       8.0           36           3   22       1.0       2.0
# 1    1.0       7.0            2           1   11       2.0       2.0
# 2    1.0       7.0            2           4   14       2.0       2.0
# 3    1.0       7.0            2           4   06       2.0       2.0
# 4    2.0       7.0           37           7   20       2.0       2.0
#
#    l_feat_3  l_feat_4  l_feat_5  ...  history_b_27  history_b_28  \
# 0       1.0       7.0     675.0  ...      0.026163      0.008176
# 1       2.0      10.0     439.0  ...      1.103450      0.344828
# 2       3.0       7.0     728.0  ...      0.074854      0.023392
# 3       2.0       1.0     615.0  ...      0.065843      0.020576
# 4       3.0       5.0     280.0  ...      0.046112      0.014410
#
#    history_b_29  history_b_30  clicked  seq_len  unique_pages  last_page  \
# 0      0.021258      0.053965        0      843            70        479
# 1      0.896553      0.568966        0       35            14        479
# 2      0.060819      0.038597        0      454            54        479
# 3      0.053498      0.067901        0      225            40        479
# 4      0.037466      0.023776        0      726            84         35
#
#    first_page  repeat_ratio
# 0           9      0.916963
# 1          57      0.600000
# 2           9      0.881057
# 3           9      0.822222
# 4         144      0.884298
#
# [5 rows x 123 columns]

# %%
X = train_df.drop(columns=['clicked'])
y = train_df['clicked']

# %%
cat_cols = X.select_dtypes(include="object").columns

for col in cat_cols:
    X[col] = X[col].astype("category")
# Out:
# /var/folders/s6/hy82dr4n1zx7lqg8r9pg6pvc0000gn/T/ipykernel_98565/718874576.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = X.select_dtypes(include="object").columns

# %%
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y, test_size=0.2, stratify=y, random_state=42
)

# Luego separas train y validation
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.25, stratify=y_temp, random_state=42
)

# %%
model = xgb.XGBClassifier(
    tree_method="hist",
    enable_categorical=True,
    max_depth=6,
    n_estimators=500,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric="auc",
    early_stopping_rounds=50,  
    random_state=42
)

# %%
model.fit(
    X_train,
    y_train,
    eval_set=[(X_train, y_train), (X_val, y_val)]
)
# Out:
# [0]	validation_0-auc:0.69514	validation_1-auc:0.69555
# [1]	validation_0-auc:0.70352	validation_1-auc:0.70288
# [2]	validation_0-auc:0.71071	validation_1-auc:0.70989
# [3]	validation_0-auc:0.71389	validation_1-auc:0.71329
# [4]	validation_0-auc:0.71590	validation_1-auc:0.71533
# [5]	validation_0-auc:0.71762	validation_1-auc:0.71683
# [6]	validation_0-auc:0.71828	validation_1-auc:0.71741
# [7]	validation_0-auc:0.71927	validation_1-auc:0.71828
# [8]	validation_0-auc:0.72000	validation_1-auc:0.71877
# [9]	validation_0-auc:0.72099	validation_1-auc:0.71958
# [10]	validation_0-auc:0.72148	validation_1-auc:0.71996
# [11]	validation_0-auc:0.72237	validation_1-auc:0.72064
# [12]	validation_0-auc:0.72283	validation_1-auc:0.72091
# [13]	validation_0-auc:0.72324	validation_1-auc:0.72131
# [14]	validation_0-auc:0.72381	validation_1-auc:0.72180
# [15]	validation_0-auc:0.72420	validation_1-auc:0.72209
# [16]	validation_0-auc:0.72476	validation_1-auc:0.72248
# [17]	validation_0-auc:0.72538	validation_1-auc:0.72302
# [18]	validation_0-auc:0.72582	validation_1-auc:0.72336
# [19]	validation_0-auc:0.72647	validation_1-auc:0.72382
# [20]	validation_0-auc:0.72682	validation_1-auc:0.72406
# [21]	validation_0-auc:0.72713	validation_1-auc:0.72431
# [22]	validation_0-auc:0.72761	validation_1-auc:0.72462
# [23]	validation_0-auc:0.72796	validation_1-auc:0.72485
# [24]	validation_0-auc:0.72823	validation_1-auc:0.72497
# [25]	validation_0-auc:0.72867	validation_1-auc:0.72533
# [26]	validation_0-auc:0.72916	validation_1-auc:0.72575
# [27]	validation_0-auc:0.72965	validation_1-auc:0.72607
# [28]	validation_0-auc:0.73003	validation_1-auc:0.72629
# [29]	validation_0-auc:0.73033	validation_1-auc:0.72653
# [30]	validation_0-auc:0.73065	validation_1-auc:0.72674
# [31]	validation_0-auc:0.73095	validation_1-auc:0.72691
# [32]	validation_0-auc:0.73129	validation_1-auc:0.72712
# [33]	validation_0-auc:0.73159	validation_1-auc:0.72734
# [34]	validation_0-auc:0.73190	validation_1-auc:0.72754
# [35]	validation_0-auc:0.73218	validation_1-auc:0.72773
# [36]	validation_0-auc:0.73256	validation_1-auc:0.72798
# [37]	validation_0-auc:0.73288	validation_1-auc:0.72826
# [38]	validation_0-auc:0.73319	validation_1-auc:0.72847
# [39]	validation_0-auc:0.73351	validation_1-auc:0.72872
# [40]	validation_0-auc:0.73372	validation_1-auc:0.72883
# [41]	validation_0-auc:0.73416	validation_1-auc:0.72911
# [42]	validation_0-auc:0.73453	validation_1-auc:0.72933
# [43]	validation_0-auc:0.73490	validation_1-auc:0.72955
# [44]	validation_0-auc:0.73515	validation_1-auc:0.72964
# [45]	validation_0-auc:0.73545	validation_1-auc:0.72980
# [46]	validation_0-auc:0.73575	validation_1-auc:0.72997
# [47]	validation_0-auc:0.73601	validation_1-auc:0.73011
# [48]	validation_0-auc:0.73624	validation_1-auc:0.73021
# [49]	validation_0-auc:0.73645	validation_1-auc:0.73031
# [50]	validation_0-auc:0.73679	validation_1-auc:0.73055
# [51]	validation_0-auc:0.73721	validation_1-auc:0.73084
# [52]	validation_0-auc:0.73743	validation_1-auc:0.73096
# [53]	validation_0-auc:0.73770	validation_1-auc:0.73106
# [54]	validation_0-auc:0.73809	validation_1-auc:0.73133
# [55]	validation_0-auc:0.73840	validation_1-auc:0.73147
# [56]	validation_0-auc:0.73865	validation_1-auc:0.73162
# [57]	validation_0-auc:0.73895	validation_1-auc:0.73183
# [58]	validation_0-auc:0.73917	validation_1-auc:0.73203
# [59]	validation_0-auc:0.73937	validation_1-auc:0.73211
# [60]	validation_0-auc:0.73967	validation_1-auc:0.73235
# [61]	validation_0-auc:0.73995	validation_1-auc:0.73245
# [62]	validation_0-auc:0.74023	validation_1-auc:0.73257
# [63]	validation_0-auc:0.74038	validation_1-auc:0.73265
# [64]	validation_0-auc:0.74059	validation_1-auc:0.73275
# [65]	validation_0-auc:0.74091	validation_1-auc:0.73298
# [66]	validation_0-auc:0.74118	validation_1-auc:0.73312
# [67]	validation_0-auc:0.74146	validation_1-auc:0.73328
# [68]	validation_0-auc:0.74172	validation_1-auc:0.73335
# [69]	validation_0-auc:0.74191	validation_1-auc:0.73339
# [70]	validation_0-auc:0.74212	validation_1-auc:0.73347
# [71]	validation_0-auc:0.74245	validation_1-auc:0.73363
# [72]	validation_0-auc:0.74270	validation_1-auc:0.73373
# [73]	validation_0-auc:0.74292	validation_1-auc:0.73382
# [74]	validation_0-auc:0.74302	validation_1-auc:0.73390
# [75]	validation_0-auc:0.74326	validation_1-auc:0.73398
# [76]	validation_0-auc:0.74345	validation_1-auc:0.73405
# [77]	validation_0-auc:0.74364	validation_1-auc:0.73411
# [78]	validation_0-auc:0.74389	validation_1-auc:0.73423
# [79]	validation_0-auc:0.74418	validation_1-auc:0.73442
# [80]	validation_0-auc:0.74437	validation_1-auc:0.73452
# [81]	validation_0-auc:0.74466	validation_1-auc:0.73470
# [82]	validation_0-auc:0.74499	validation_1-auc:0.73494
# [83]	validation_0-auc:0.74525	validation_1-auc:0.73509
# [84]	validation_0-auc:0.74545	validation_1-auc:0.73519
# [85]	validation_0-auc:0.74566	validation_1-auc:0.73525
# [86]	validation_0-auc:0.74586	validation_1-auc:0.73537
# [87]	validation_0-auc:0.74617	validation_1-auc:0.73558
# [88]	validation_0-auc:0.74644	validation_1-auc:0.73573
# [89]	validation_0-auc:0.74663	validation_1-auc:0.73579
# [90]	validation_0-auc:0.74683	validation_1-auc:0.73586
# [91]	validation_0-auc:0.74699	validation_1-auc:0.73594
# [92]	validation_0-auc:0.74718	validation_1-auc:0.73601
# [93]	validation_0-auc:0.74740	validation_1-auc:0.73613
# [94]	validation_0-auc:0.74755	validation_1-auc:0.73616
# [95]	validation_0-auc:0.74773	validation_1-auc:0.73621
# [96]	validation_0-auc:0.74798	validation_1-auc:0.73635
# [97]	validation_0-auc:0.74818	validation_1-auc:0.73640
# [98]	validation_0-auc:0.74839	validation_1-auc:0.73648
# [99]	validation_0-auc:0.74858	validation_1-auc:0.73657
# [100]	validation_0-auc:0.74876	validation_1-auc:0.73665
# [101]	validation_0-auc:0.74901	validation_1-auc:0.73678
# [102]	validation_0-auc:0.74920	validation_1-auc:0.73684
# [103]	validation_0-auc:0.74934	validation_1-auc:0.73689
# [104]	validation_0-auc:0.74952	validation_1-auc:0.73695
# [105]	validation_0-auc:0.74964	validation_1-auc:0.73698
# [106]	validation_0-auc:0.74980	validation_1-auc:0.73707
# [107]	validation_0-auc:0.74998	validation_1-auc:0.73713
# [108]	validation_0-auc:0.75015	validation_1-auc:0.73723
# [109]	validation_0-auc:0.75029	validation_1-auc:0.73729
# [110]	validation_0-auc:0.75050	validation_1-auc:0.73733
# [111]	validation_0-auc:0.75067	validation_1-auc:0.73736
# [112]	validation_0-auc:0.75083	validation_1-auc:0.73738
# [113]	validation_0-auc:0.75095	validation_1-auc:0.73745
# [114]	validation_0-auc:0.75110	validation_1-auc:0.73751
# [115]	validation_0-auc:0.75123	validation_1-auc:0.73755
# [116]	validation_0-auc:0.75146	validation_1-auc:0.73768
# [117]	validation_0-auc:0.75163	validation_1-auc:0.73770
# [118]	validation_0-auc:0.75176	validation_1-auc:0.73773
# [119]	validation_0-auc:0.75189	validation_1-auc:0.73776
# [120]	validation_0-auc:0.75207	validation_1-auc:0.73785
# [121]	validation_0-auc:0.75222	validation_1-auc:0.73794
# [122]	validation_0-auc:0.75235	validation_1-auc:0.73795
# [123]	validation_0-auc:0.75248	validation_1-auc:0.73795
# [124]	validation_0-auc:0.75265	validation_1-auc:0.73797
# [125]	validation_0-auc:0.75285	validation_1-auc:0.73806
# [126]	validation_0-auc:0.75300	validation_1-auc:0.73810
# [127]	validation_0-auc:0.75315	validation_1-auc:0.73811
# [128]	validation_0-auc:0.75330	validation_1-auc:0.73815
# [129]	validation_0-auc:0.75347	validation_1-auc:0.73823
# [130]	validation_0-auc:0.75365	validation_1-auc:0.73830
# [131]	validation_0-auc:0.75374	validation_1-auc:0.73833
# [132]	validation_0-auc:0.75391	validation_1-auc:0.73835
# [133]	validation_0-auc:0.75407	validation_1-auc:0.73839
# [134]	validation_0-auc:0.75421	validation_1-auc:0.73843
# [135]	validation_0-auc:0.75446	validation_1-auc:0.73851
# [136]	validation_0-auc:0.75464	validation_1-auc:0.73858
# [137]	validation_0-auc:0.75475	validation_1-auc:0.73857
# [138]	validation_0-auc:0.75490	validation_1-auc:0.73860
# [139]	validation_0-auc:0.75507	validation_1-auc:0.73864
# [140]	validation_0-auc:0.75523	validation_1-auc:0.73869
# [141]	validation_0-auc:0.75538	validation_1-auc:0.73873
# [142]	validation_0-auc:0.75547	validation_1-auc:0.73875
# [143]	validation_0-auc:0.75558	validation_1-auc:0.73879
# [144]	validation_0-auc:0.75574	validation_1-auc:0.73882
# [145]	validation_0-auc:0.75591	validation_1-auc:0.73886
# [146]	validation_0-auc:0.75609	validation_1-auc:0.73888
# [147]	validation_0-auc:0.75625	validation_1-auc:0.73894
# [148]	validation_0-auc:0.75637	validation_1-auc:0.73898
# [149]	validation_0-auc:0.75655	validation_1-auc:0.73908
# [150]	validation_0-auc:0.75676	validation_1-auc:0.73915
# [151]	validation_0-auc:0.75692	validation_1-auc:0.73919
# [152]	validation_0-auc:0.75702	validation_1-auc:0.73921
# [153]	validation_0-auc:0.75713	validation_1-auc:0.73921
# [154]	validation_0-auc:0.75731	validation_1-auc:0.73926
# [155]	validation_0-auc:0.75742	validation_1-auc:0.73927
# [156]	validation_0-auc:0.75756	validation_1-auc:0.73932
# [157]	validation_0-auc:0.75770	validation_1-auc:0.73936
# [158]	validation_0-auc:0.75780	validation_1-auc:0.73937
# [159]	validation_0-auc:0.75790	validation_1-auc:0.73938
# [160]	validation_0-auc:0.75802	validation_1-auc:0.73940
# [161]	validation_0-auc:0.75818	validation_1-auc:0.73943
# [162]	validation_0-auc:0.75831	validation_1-auc:0.73946
# [163]	validation_0-auc:0.75839	validation_1-auc:0.73948
# [164]	validation_0-auc:0.75855	validation_1-auc:0.73948
# [165]	validation_0-auc:0.75875	validation_1-auc:0.73952
# [166]	validation_0-auc:0.75888	validation_1-auc:0.73956
# [167]	validation_0-auc:0.75901	validation_1-auc:0.73957
# [168]	validation_0-auc:0.75916	validation_1-auc:0.73960
# [169]	validation_0-auc:0.75931	validation_1-auc:0.73963
# [170]	validation_0-auc:0.75944	validation_1-auc:0.73964
# [171]	validation_0-auc:0.75959	validation_1-auc:0.73965
# [172]	validation_0-auc:0.75969	validation_1-auc:0.73966
# [173]	validation_0-auc:0.75983	validation_1-auc:0.73966
# [174]	validation_0-auc:0.75999	validation_1-auc:0.73968
# [175]	validation_0-auc:0.76013	validation_1-auc:0.73968
# [176]	validation_0-auc:0.76019	validation_1-auc:0.73969
# [177]	validation_0-auc:0.76031	validation_1-auc:0.73972
# [178]	validation_0-auc:0.76045	validation_1-auc:0.73975
# [179]	validation_0-auc:0.76063	validation_1-auc:0.73979
# [180]	validation_0-auc:0.76079	validation_1-auc:0.73984
# [181]	validation_0-auc:0.76091	validation_1-auc:0.73989
# [182]	validation_0-auc:0.76106	validation_1-auc:0.73992
# [183]	validation_0-auc:0.76114	validation_1-auc:0.73991
# [184]	validation_0-auc:0.76128	validation_1-auc:0.73994
# [185]	validation_0-auc:0.76141	validation_1-auc:0.73997
# [186]	validation_0-auc:0.76159	validation_1-auc:0.73998
# [187]	validation_0-auc:0.76171	validation_1-auc:0.74000
# [188]	validation_0-auc:0.76183	validation_1-auc:0.74001
# [189]	validation_0-auc:0.76196	validation_1-auc:0.74001
# [190]	validation_0-auc:0.76202	validation_1-auc:0.74001
# [191]	validation_0-auc:0.76222	validation_1-auc:0.74002
# [192]	validation_0-auc:0.76231	validation_1-auc:0.74002
# [193]	validation_0-auc:0.76244	validation_1-auc:0.74006
# [194]	validation_0-auc:0.76257	validation_1-auc:0.74008
# [195]	validation_0-auc:0.76273	validation_1-auc:0.74012
# [196]	validation_0-auc:0.76286	validation_1-auc:0.74013
# [197]	validation_0-auc:0.76290	validation_1-auc:0.74014
# [198]	validation_0-auc:0.76302	validation_1-auc:0.74016
# [199]	validation_0-auc:0.76313	validation_1-auc:0.74014
# [200]	validation_0-auc:0.76331	validation_1-auc:0.74016
# [201]	validation_0-auc:0.76342	validation_1-auc:0.74018
# [202]	validation_0-auc:0.76355	validation_1-auc:0.74020
# [203]	validation_0-auc:0.76369	validation_1-auc:0.74023
# [204]	validation_0-auc:0.76384	validation_1-auc:0.74025
# [205]	validation_0-auc:0.76398	validation_1-auc:0.74027
# [206]	validation_0-auc:0.76407	validation_1-auc:0.74028
# [207]	validation_0-auc:0.76415	validation_1-auc:0.74030
# [208]	validation_0-auc:0.76430	validation_1-auc:0.74028
# [209]	validation_0-auc:0.76438	validation_1-auc:0.74027
# [210]	validation_0-auc:0.76455	validation_1-auc:0.74026
# [211]	validation_0-auc:0.76470	validation_1-auc:0.74031
# [212]	validation_0-auc:0.76480	validation_1-auc:0.74030
# [213]	validation_0-auc:0.76498	validation_1-auc:0.74034
# [214]	validation_0-auc:0.76507	validation_1-auc:0.74035
# [215]	validation_0-auc:0.76512	validation_1-auc:0.74037
# [216]	validation_0-auc:0.76522	validation_1-auc:0.74039
# [217]	validation_0-auc:0.76535	validation_1-auc:0.74041
# [218]	validation_0-auc:0.76541	validation_1-auc:0.74040
# [219]	validation_0-auc:0.76554	validation_1-auc:0.74039
# [220]	validation_0-auc:0.76567	validation_1-auc:0.74040
# [221]	validation_0-auc:0.76573	validation_1-auc:0.74042
# [222]	validation_0-auc:0.76581	validation_1-auc:0.74042
# [223]	validation_0-auc:0.76593	validation_1-auc:0.74044
# [224]	validation_0-auc:0.76603	validation_1-auc:0.74045
# [225]	validation_0-auc:0.76612	validation_1-auc:0.74044
# [226]	validation_0-auc:0.76621	validation_1-auc:0.74046
# [227]	validation_0-auc:0.76636	validation_1-auc:0.74045
# [228]	validation_0-auc:0.76641	validation_1-auc:0.74045
# [229]	validation_0-auc:0.76655	validation_1-auc:0.74047
# [230]	validation_0-auc:0.76670	validation_1-auc:0.74049
# [231]	validation_0-auc:0.76682	validation_1-auc:0.74049
# [232]	validation_0-auc:0.76692	validation_1-auc:0.74050
# [233]	validation_0-auc:0.76705	validation_1-auc:0.74049
# [234]	validation_0-auc:0.76711	validation_1-auc:0.74048
# [235]	validation_0-auc:0.76719	validation_1-auc:0.74050
# [236]	validation_0-auc:0.76723	validation_1-auc:0.74051
# [237]	validation_0-auc:0.76733	validation_1-auc:0.74053
# [238]	validation_0-auc:0.76747	validation_1-auc:0.74055
# [239]	validation_0-auc:0.76759	validation_1-auc:0.74056
# [240]	validation_0-auc:0.76771	validation_1-auc:0.74058
# [241]	validation_0-auc:0.76785	validation_1-auc:0.74058
# [242]	validation_0-auc:0.76796	validation_1-auc:0.74062
# [243]	validation_0-auc:0.76804	validation_1-auc:0.74064
# [244]	validation_0-auc:0.76816	validation_1-auc:0.74066
# [245]	validation_0-auc:0.76830	validation_1-auc:0.74068
# [246]	validation_0-auc:0.76839	validation_1-auc:0.74067
# [247]	validation_0-auc:0.76846	validation_1-auc:0.74068
# [248]	validation_0-auc:0.76860	validation_1-auc:0.74071
# [249]	validation_0-auc:0.76867	validation_1-auc:0.74072
# [250]	validation_0-auc:0.76880	validation_1-auc:0.74074
# [251]	validation_0-auc:0.76889	validation_1-auc:0.74074
# [252]	validation_0-auc:0.76900	validation_1-auc:0.74074
# [253]	validation_0-auc:0.76914	validation_1-auc:0.74074
# [254]	validation_0-auc:0.76921	validation_1-auc:0.74074
# [255]	validation_0-auc:0.76929	validation_1-auc:0.74075
# [256]	validation_0-auc:0.76941	validation_1-auc:0.74074
# [257]	validation_0-auc:0.76957	validation_1-auc:0.74076
# [258]	validation_0-auc:0.76967	validation_1-auc:0.74077
# [259]	validation_0-auc:0.76978	validation_1-auc:0.74078
# [260]	validation_0-auc:0.76989	validation_1-auc:0.74079
# [261]	validation_0-auc:0.77002	validation_1-auc:0.74082
# [262]	validation_0-auc:0.77013	validation_1-auc:0.74082
# [263]	validation_0-auc:0.77028	validation_1-auc:0.74081
# [264]	validation_0-auc:0.77041	validation_1-auc:0.74081
# [265]	validation_0-auc:0.77052	validation_1-auc:0.74080
# [266]	validation_0-auc:0.77066	validation_1-auc:0.74080
# [267]	validation_0-auc:0.77078	validation_1-auc:0.74082
# [268]	validation_0-auc:0.77092	validation_1-auc:0.74084
# [269]	validation_0-auc:0.77102	validation_1-auc:0.74084
# [270]	validation_0-auc:0.77109	validation_1-auc:0.74085
# [271]	validation_0-auc:0.77119	validation_1-auc:0.74087
# [272]	validation_0-auc:0.77137	validation_1-auc:0.74086
# [273]	validation_0-auc:0.77152	validation_1-auc:0.74086
# [274]	validation_0-auc:0.77165	validation_1-auc:0.74086
# [275]	validation_0-auc:0.77173	validation_1-auc:0.74086
# [276]	validation_0-auc:0.77184	validation_1-auc:0.74089
# [277]	validation_0-auc:0.77195	validation_1-auc:0.74090
# [278]	validation_0-auc:0.77208	validation_1-auc:0.74092
# [279]	validation_0-auc:0.77221	validation_1-auc:0.74092
# [280]	validation_0-auc:0.77230	validation_1-auc:0.74093
# [281]	validation_0-auc:0.77241	validation_1-auc:0.74094
# [282]	validation_0-auc:0.77253	validation_1-auc:0.74094
# [283]	validation_0-auc:0.77267	validation_1-auc:0.74094
# [284]	validation_0-auc:0.77275	validation_1-auc:0.74096
# [285]	validation_0-auc:0.77291	validation_1-auc:0.74098
# [286]	validation_0-auc:0.77302	validation_1-auc:0.74099
# [287]	validation_0-auc:0.77313	validation_1-auc:0.74099
# [288]	validation_0-auc:0.77324	validation_1-auc:0.74100
# [289]	validation_0-auc:0.77334	validation_1-auc:0.74101
# [290]	validation_0-auc:0.77347	validation_1-auc:0.74102
# [291]	validation_0-auc:0.77361	validation_1-auc:0.74101
# [292]	validation_0-auc:0.77365	validation_1-auc:0.74101
# [293]	validation_0-auc:0.77374	validation_1-auc:0.74101
# [294]	validation_0-auc:0.77378	validation_1-auc:0.74101
# [295]	validation_0-auc:0.77389	validation_1-auc:0.74103
# [296]	validation_0-auc:0.77399	validation_1-auc:0.74105
# [297]	validation_0-auc:0.77413	validation_1-auc:0.74106
# [298]	validation_0-auc:0.77425	validation_1-auc:0.74112
# [299]	validation_0-auc:0.77434	validation_1-auc:0.74111
# [300]	validation_0-auc:0.77441	validation_1-auc:0.74110
# [301]	validation_0-auc:0.77452	validation_1-auc:0.74111
# [302]	validation_0-auc:0.77462	validation_1-auc:0.74113
# [303]	validation_0-auc:0.77469	validation_1-auc:0.74113
# [304]	validation_0-auc:0.77478	validation_1-auc:0.74114
# [305]	validation_0-auc:0.77493	validation_1-auc:0.74114
# [306]	validation_0-auc:0.77500	validation_1-auc:0.74114
# [307]	validation_0-auc:0.77510	validation_1-auc:0.74114
# [308]	validation_0-auc:0.77520	validation_1-auc:0.74114
# [309]	validation_0-auc:0.77527	validation_1-auc:0.74114
# [310]	validation_0-auc:0.77540	validation_1-auc:0.74116
# [311]	validation_0-auc:0.77549	validation_1-auc:0.74116
# [312]	validation_0-auc:0.77562	validation_1-auc:0.74121
# [313]	validation_0-auc:0.77570	validation_1-auc:0.74120
# [314]	validation_0-auc:0.77578	validation_1-auc:0.74120
# [315]	validation_0-auc:0.77588	validation_1-auc:0.74118
# [316]	validation_0-auc:0.77598	validation_1-auc:0.74117
# [317]	validation_0-auc:0.77610	validation_1-auc:0.74117
# [318]	validation_0-auc:0.77619	validation_1-auc:0.74118
# [319]	validation_0-auc:0.77631	validation_1-auc:0.74121
# [320]	validation_0-auc:0.77644	validation_1-auc:0.74122
# [321]	validation_0-auc:0.77658	validation_1-auc:0.74124
# [322]	validation_0-auc:0.77661	validation_1-auc:0.74125
# [323]	validation_0-auc:0.77676	validation_1-auc:0.74123
# [324]	validation_0-auc:0.77688	validation_1-auc:0.74125
# [325]	validation_0-auc:0.77702	validation_1-auc:0.74126
# [326]	validation_0-auc:0.77712	validation_1-auc:0.74126
# [327]	validation_0-auc:0.77716	validation_1-auc:0.74125
# [328]	validation_0-auc:0.77724	validation_1-auc:0.74125
# [329]	validation_0-auc:0.77743	validation_1-auc:0.74124
# [330]	validation_0-auc:0.77756	validation_1-auc:0.74125
# [331]	validation_0-auc:0.77766	validation_1-auc:0.74124
# [332]	validation_0-auc:0.77779	validation_1-auc:0.74130
# [333]	validation_0-auc:0.77789	validation_1-auc:0.74131
# [334]	validation_0-auc:0.77794	validation_1-auc:0.74132
# [335]	validation_0-auc:0.77804	validation_1-auc:0.74131
# [336]	validation_0-auc:0.77809	validation_1-auc:0.74132
# [337]	validation_0-auc:0.77819	validation_1-auc:0.74133
# [338]	validation_0-auc:0.77828	validation_1-auc:0.74136
# [339]	validation_0-auc:0.77834	validation_1-auc:0.74136
# [340]	validation_0-auc:0.77844	validation_1-auc:0.74137
# [341]	validation_0-auc:0.77855	validation_1-auc:0.74135
# [342]	validation_0-auc:0.77865	validation_1-auc:0.74137
# [343]	validation_0-auc:0.77876	validation_1-auc:0.74140
# [344]	validation_0-auc:0.77883	validation_1-auc:0.74141
# [345]	validation_0-auc:0.77895	validation_1-auc:0.74140
# [346]	validation_0-auc:0.77909	validation_1-auc:0.74140
# [347]	validation_0-auc:0.77919	validation_1-auc:0.74139
# [348]	validation_0-auc:0.77931	validation_1-auc:0.74141
# [349]	validation_0-auc:0.77935	validation_1-auc:0.74142
# [350]	validation_0-auc:0.77949	validation_1-auc:0.74142
# [351]	validation_0-auc:0.77959	validation_1-auc:0.74143
# [352]	validation_0-auc:0.77967	validation_1-auc:0.74143
# [353]	validation_0-auc:0.77977	validation_1-auc:0.74141
# [354]	validation_0-auc:0.77984	validation_1-auc:0.74140
# [355]	validation_0-auc:0.77995	validation_1-auc:0.74141
# [356]	validation_0-auc:0.78000	validation_1-auc:0.74142
# [357]	validation_0-auc:0.78010	validation_1-auc:0.74142
# [358]	validation_0-auc:0.78018	validation_1-auc:0.74141
# [359]	validation_0-auc:0.78027	validation_1-auc:0.74141
# [360]	validation_0-auc:0.78035	validation_1-auc:0.74141
# [361]	validation_0-auc:0.78042	validation_1-auc:0.74141
# [362]	validation_0-auc:0.78051	validation_1-auc:0.74141
# [363]	validation_0-auc:0.78064	validation_1-auc:0.74145
# [364]	validation_0-auc:0.78080	validation_1-auc:0.74149
# [365]	validation_0-auc:0.78088	validation_1-auc:0.74149
# [366]	validation_0-auc:0.78102	validation_1-auc:0.74152
# [367]	validation_0-auc:0.78113	validation_1-auc:0.74156
# [368]	validation_0-auc:0.78120	validation_1-auc:0.74155
# [369]	validation_0-auc:0.78132	validation_1-auc:0.74157
# [370]	validation_0-auc:0.78141	validation_1-auc:0.74158
# [371]	validation_0-auc:0.78151	validation_1-auc:0.74157
# [372]	validation_0-auc:0.78157	validation_1-auc:0.74157
# [373]	validation_0-auc:0.78163	validation_1-auc:0.74158
# [374]	validation_0-auc:0.78172	validation_1-auc:0.74157
# [375]	validation_0-auc:0.78180	validation_1-auc:0.74157
# [376]	validation_0-auc:0.78189	validation_1-auc:0.74157
# [377]	validation_0-auc:0.78198	validation_1-auc:0.74158
# [378]	validation_0-auc:0.78211	validation_1-auc:0.74158
# [379]	validation_0-auc:0.78220	validation_1-auc:0.74159
# [380]	validation_0-auc:0.78230	validation_1-auc:0.74160
# [381]	validation_0-auc:0.78241	validation_1-auc:0.74160
# [382]	validation_0-auc:0.78246	validation_1-auc:0.74161
# [383]	validation_0-auc:0.78253	validation_1-auc:0.74160
# [384]	validation_0-auc:0.78263	validation_1-auc:0.74161
# [385]	validation_0-auc:0.78268	validation_1-auc:0.74160
# [386]	validation_0-auc:0.78276	validation_1-auc:0.74161
# [387]	validation_0-auc:0.78289	validation_1-auc:0.74160
# [388]	validation_0-auc:0.78302	validation_1-auc:0.74159
# [389]	validation_0-auc:0.78308	validation_1-auc:0.74158
# [390]	validation_0-auc:0.78319	validation_1-auc:0.74160
# [391]	validation_0-auc:0.78334	validation_1-auc:0.74162
# [392]	validation_0-auc:0.78340	validation_1-auc:0.74162
# [393]	validation_0-auc:0.78354	validation_1-auc:0.74165
# [394]	validation_0-auc:0.78364	validation_1-auc:0.74166
# [395]	validation_0-auc:0.78376	validation_1-auc:0.74168
# [396]	validation_0-auc:0.78381	validation_1-auc:0.74167
# [397]	validation_0-auc:0.78390	validation_1-auc:0.74168
# [398]	validation_0-auc:0.78400	validation_1-auc:0.74167
# [399]	validation_0-auc:0.78405	validation_1-auc:0.74168
# [400]	validation_0-auc:0.78411	validation_1-auc:0.74169
# [401]	validation_0-auc:0.78415	validation_1-auc:0.74168
# [402]	validation_0-auc:0.78425	validation_1-auc:0.74169
# [403]	validation_0-auc:0.78437	validation_1-auc:0.74169
# [404]	validation_0-auc:0.78449	validation_1-auc:0.74171
# [405]	validation_0-auc:0.78455	validation_1-auc:0.74172
# [406]	validation_0-auc:0.78462	validation_1-auc:0.74173
# [407]	validation_0-auc:0.78472	validation_1-auc:0.74174
# [408]	validation_0-auc:0.78478	validation_1-auc:0.74174
# [409]	validation_0-auc:0.78482	validation_1-auc:0.74173
# [410]	validation_0-auc:0.78491	validation_1-auc:0.74174
# [411]	validation_0-auc:0.78499	validation_1-auc:0.74175
# [412]	validation_0-auc:0.78505	validation_1-auc:0.74177
# [413]	validation_0-auc:0.78516	validation_1-auc:0.74178
# [414]	validation_0-auc:0.78524	validation_1-auc:0.74177
# [415]	validation_0-auc:0.78536	validation_1-auc:0.74178
# [416]	validation_0-auc:0.78547	validation_1-auc:0.74181
# [417]	validation_0-auc:0.78554	validation_1-auc:0.74182
# [418]	validation_0-auc:0.78563	validation_1-auc:0.74182
# [419]	validation_0-auc:0.78575	validation_1-auc:0.74181
# [420]	validation_0-auc:0.78581	validation_1-auc:0.74179
# [421]	validation_0-auc:0.78592	validation_1-auc:0.74181
# [422]	validation_0-auc:0.78598	validation_1-auc:0.74180
# [423]	validation_0-auc:0.78604	validation_1-auc:0.74181
# [424]	validation_0-auc:0.78616	validation_1-auc:0.74181
# [425]	validation_0-auc:0.78625	validation_1-auc:0.74180
# [426]	validation_0-auc:0.78634	validation_1-auc:0.74180
# [427]	validation_0-auc:0.78645	validation_1-auc:0.74182
# [428]	validation_0-auc:0.78657	validation_1-auc:0.74181
# [429]	validation_0-auc:0.78664	validation_1-auc:0.74184
# [430]	validation_0-auc:0.78671	validation_1-auc:0.74184
# [431]	validation_0-auc:0.78673	validation_1-auc:0.74185
# [432]	validation_0-auc:0.78686	validation_1-auc:0.74187
# [433]	validation_0-auc:0.78690	validation_1-auc:0.74186
# [434]	validation_0-auc:0.78699	validation_1-auc:0.74187
# [435]	validation_0-auc:0.78709	validation_1-auc:0.74187
# [436]	validation_0-auc:0.78723	validation_1-auc:0.74185
# [437]	validation_0-auc:0.78734	validation_1-auc:0.74183
# [438]	validation_0-auc:0.78740	validation_1-auc:0.74183
# [439]	validation_0-auc:0.78749	validation_1-auc:0.74183
# [440]	validation_0-auc:0.78761	validation_1-auc:0.74183
# [441]	validation_0-auc:0.78772	validation_1-auc:0.74183
# [442]	validation_0-auc:0.78781	validation_1-auc:0.74181
# [443]	validation_0-auc:0.78793	validation_1-auc:0.74181
# [444]	validation_0-auc:0.78804	validation_1-auc:0.74182
# [445]	validation_0-auc:0.78812	validation_1-auc:0.74183
# [446]	validation_0-auc:0.78823	validation_1-auc:0.74187
# [447]	validation_0-auc:0.78831	validation_1-auc:0.74188
# [448]	validation_0-auc:0.78840	validation_1-auc:0.74186
# [449]	validation_0-auc:0.78847	validation_1-auc:0.74184
# [450]	validation_0-auc:0.78860	validation_1-auc:0.74184
# [451]	validation_0-auc:0.78869	validation_1-auc:0.74187
# [452]	validation_0-auc:0.78876	validation_1-auc:0.74189
# [453]	validation_0-auc:0.78879	validation_1-auc:0.74190
# [454]	validation_0-auc:0.78889	validation_1-auc:0.74190
# [455]	validation_0-auc:0.78897	validation_1-auc:0.74188
# [456]	validation_0-auc:0.78902	validation_1-auc:0.74189
# [457]	validation_0-auc:0.78910	validation_1-auc:0.74188
# [458]	validation_0-auc:0.78926	validation_1-auc:0.74192
# [459]	validation_0-auc:0.78935	validation_1-auc:0.74191
# [460]	validation_0-auc:0.78943	validation_1-auc:0.74191
# [461]	validation_0-auc:0.78949	validation_1-auc:0.74191
# [462]	validation_0-auc:0.78956	validation_1-auc:0.74191
# [463]	validation_0-auc:0.78965	validation_1-auc:0.74192
# [464]	validation_0-auc:0.78974	validation_1-auc:0.74192
# [465]	validation_0-auc:0.78983	validation_1-auc:0.74192
# [466]	validation_0-auc:0.78995	validation_1-auc:0.74194
# [467]	validation_0-auc:0.79002	validation_1-auc:0.74194
# [468]	validation_0-auc:0.79011	validation_1-auc:0.74195
# [469]	validation_0-auc:0.79019	validation_1-auc:0.74196
# [470]	validation_0-auc:0.79028	validation_1-auc:0.74196
# [471]	validation_0-auc:0.79039	validation_1-auc:0.74196
# [472]	validation_0-auc:0.79047	validation_1-auc:0.74196
# [473]	validation_0-auc:0.79057	validation_1-auc:0.74198
# [474]	validation_0-auc:0.79068	validation_1-auc:0.74198
# [475]	validation_0-auc:0.79077	validation_1-auc:0.74199
# [476]	validation_0-auc:0.79085	validation_1-auc:0.74199
# [477]	validation_0-auc:0.79092	validation_1-auc:0.74198
# [478]	validation_0-auc:0.79103	validation_1-auc:0.74197
# [479]	validation_0-auc:0.79112	validation_1-auc:0.74193
# [480]	validation_0-auc:0.79116	validation_1-auc:0.74192
# [481]	validation_0-auc:0.79127	validation_1-auc:0.74192
# [482]	validation_0-auc:0.79135	validation_1-auc:0.74192
# [483]	validation_0-auc:0.79142	validation_1-auc:0.74192
# [484]	validation_0-auc:0.79151	validation_1-auc:0.74193
# [485]	validation_0-auc:0.79160	validation_1-auc:0.74193
# [486]	validation_0-auc:0.79171	validation_1-auc:0.74193
# [487]	validation_0-auc:0.79181	validation_1-auc:0.74195
# [488]	validation_0-auc:0.79191	validation_1-auc:0.74195
# [489]	validation_0-auc:0.79202	validation_1-auc:0.74196
# [490]	validation_0-auc:0.79203	validation_1-auc:0.74196
# [491]	validation_0-auc:0.79209	validation_1-auc:0.74196
# [492]	validation_0-auc:0.79221	validation_1-auc:0.74198
# [493]	validation_0-auc:0.79224	validation_1-auc:0.74197
# [494]	validation_0-auc:0.79234	validation_1-auc:0.74196
# [495]	validation_0-auc:0.79242	validation_1-auc:0.74195
# [496]	validation_0-auc:0.79252	validation_1-auc:0.74198
# [497]	validation_0-auc:0.79260	validation_1-auc:0.74199
# [498]	validation_0-auc:0.79270	validation_1-auc:0.74198
# [499]	validation_0-auc:0.79276	validation_1-auc:0.74199
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=50,
#               enable_categorical=True, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
print(roc_auc_score(y_test, model.predict_proba(X_test)[:,1]))
# Out:
# 0.7417952843252247

# %%
print(roc_auc_score(y_val, model.predict_proba(X_val)[:,1]))
# Out:
# 0.7420259327077228
